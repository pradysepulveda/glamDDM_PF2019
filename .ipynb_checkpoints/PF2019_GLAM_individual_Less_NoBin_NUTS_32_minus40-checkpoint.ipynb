# %%
import glam
import pandas as pd
import numpy as np
import os.path

import matplotlib.pyplot as plt

# %%
import pymc3 as pm

# %%
np.random.seed(23) # from random.org

# %% [markdown]
# # 3.1. Hierarchical GLAM estimation and out of sample prediction

# %% [markdown]
# ## Load data

# %%
# Load data
sufix = '_individual_Less_NoBin_Gamma-11_NUTS_33'
data = pd.read_csv('data/PF2019_data/GlamDataPF2019_Less_NoBin_33.csv')

# Subset only necessary columns
data = data[['subject', 'trial', 'choice', 'rt',
         'item_value_0', 'item_value_1',
         'gaze_0', 'gaze_1']]
data.head()
# Out:
#    subject  trial  choice        rt  item_value_0  item_value_1    gaze_0  \
# 0        1      0       0  4261.735           110           131  0.603448
# 1        1      1       1  3559.258            47            50  0.490772
# 2        1      2       1  3754.464            50            44  0.490893
# 3        1      3       0  2431.751            57            50  0.639125
# 4        1      4       0  2199.342            42            50  0.702232
#
#      gaze_1
# 0  0.396552
# 1  0.509228
# 2  0.509107
# 3  0.360875
# 4  0.297768

# %% [markdown]
# ## Split data in training and test sets

# %%
train_data = pd.DataFrame()
test_data = pd.DataFrame()

for subject in data.subject.unique():
    subject_data = data[data['subject'] == subject].copy().reset_index(drop=True)
    n_trials = len(subject_data)
    
    subject_train = subject_data.iloc[np.arange(0, n_trials, 2)].copy()
    subject_test = subject_data.iloc[np.arange(1, n_trials, 2)].copy()

    test_data = pd.concat([test_data, subject_test])
    train_data = pd.concat([train_data, subject_train])

test_data.to_csv(str('data/PF2019_data/GlamDataPF2019_preprocessed_test'+sufix+'.csv'))
train_data.to_csv(str('data/PF2019_data/GlamDataPF2019_preprocessed_train'+sufix+'.csv'))

print('Split data into training ({} trials) and test ({} trials) sets...'.format(len(train_data), len(test_data)))
# Out:
# Split data into training (1920 trials) and test (1920 trials) sets...

# %%
train_data
# Out:
#      subject  trial  choice        rt  item_value_0  item_value_1    gaze_0  \
# 0          1      0       0  4261.735           110           131  0.603448
# 2          1      2       1  3754.464            50            44  0.490893
# 4          1      4       0  2199.342            42            50  0.702232
# 6          1      6       0  6606.698            78            80  0.602831
# 8          1      8       1  5213.480            50            48  0.475195
# 10         1     10       0  2007.957            46            50  0.638397
# 12         1     12       0  1978.076            50            56  0.605235
# 14         1     14       1  3907.246           110           124  0.479771
# 16         1     16       0  1823.377            64            80  0.629489
# 18         1     18       0  4920.474           101           110  0.694959
# 20         1     20       0  1705.811            50            42  0.636436
# 22         1     22       0  2474.714            77            80  0.642971
# 24         1     24       0  3790.480            44            50  0.565495
# 26         1     26       1  3822.251            50            46  0.468667
# 28         1     28       1  2252.245           133           110  0.519646
# 30         1     30       1  4155.502           126           110  0.670523
# 32         1     32       0  5814.551           110           126  0.763474
# 34         1     34       0  1743.991            80            77  0.657066
# 36         1     36       1  3381.750            80            64  0.627425
# 38         1     38       1  3602.313           124           110  0.470957
# 40         1     40       1  7964.301           128           110  0.539804
# 42         1     42       0  2122.334            54            50  0.699431
# 44         1     44       0  2201.475           105           110  0.585813
# 46         1     46       0  2017.429            96            80  0.671605
# 48         1     48       0  2528.386           110           128  0.717070
# 50         1     50       0  1513.221           110           119  0.638326
# 52         1     52       0  3815.203            58            50  0.563237
# 54         1     54       0  3013.624            74            80  0.474341
# 56         1     56       0  1818.684            66            80  0.665297
# 58         1     58       0  3156.807            94           110  0.764561
# ..       ...    ...     ...       ...           ...           ...       ...
# 60        33     60       0  5574.181            75            80  0.473662
# 62        33     62       0  1623.716            89           110  0.581980
# 64        33     64       1  5266.289           110            98  0.485209
# 66        33     66       1  4480.192           110            94  0.480105
# 68        33     68       1  2559.781            50            54  0.416775
# 70        33     70       1  4939.104            50            52  0.480362
# 72        33     72       0  3524.365            87           110  0.515382
# 74        33     74       0  4286.780            80            96  0.495837
# 76        33     76       0  4953.792            50            55  0.505023
# 78        33     78       0  1525.091            45            50  0.535368
# 80        33     80       1  5318.646            50            53  0.571120
# 82        33     82       0  1867.922            80            88  0.612229
# 84        33     84       0  4005.469           103           110  0.416217
# 86        33     86       0  4756.104            80            72  0.413177
# 88        33     88       0  2002.718            80            90  0.633215
# 90        33     90       1  2154.276            80            70  0.499230
# 92        33     92       1  3600.589            82            80  0.500618
# 94        33     94       0  3099.150            96           110  0.469571
# 96        33     96       1  4201.412            60            50  0.466509
# 98        33     98       1  2128.968           110            96  0.465549
# 100       33    100       0  2593.981            49            50  0.572452
# 102       33    102       1  3422.548            51            50  0.421237
# 104       33    104       0  3026.628            40            50  0.599172
# 106       33    106       1  4261.328            85            80  0.426795
# 108       33    108       1  2831.685            50            43  0.406985
# 110       33    110       0  1522.433            50            60  0.500810
# 112       33    112       1  2271.982           122           110  0.500242
# 114       33    114       1  3589.465            80            67  0.494589
# 116       33    116       0  6127.148           110           122  0.454173
# 118       33    118       1  3218.693           110           112  0.475219
#
#        gaze_1
# 0    0.396552
# 2    0.509107
# 4    0.297768
# 6    0.397169
# 8    0.524805
# 10   0.361603
# 12   0.394765
# 14   0.520229
# 16   0.370511
# 18   0.305041
# 20   0.363564
# 22   0.357029
# 24   0.434505
# 26   0.531333
# 28   0.480354
# 30   0.329477
# 32   0.236526
# 34   0.342934
# 36   0.372575
# 38   0.529043
# 40   0.460196
# 42   0.300569
# 44   0.414187
# 46   0.328395
# 48   0.282930
# 50   0.361674
# 52   0.436763
# 54   0.525659
# 56   0.334703
# 58   0.235439
# ..        ...
# 60   0.526338
# 62   0.418020
# 64   0.514791
# 66   0.519895
# 68   0.583225
# 70   0.519638
# 72   0.484618
# 74   0.504163
# 76   0.494977
# 78   0.464632
# 80   0.428880
# 82   0.387771
# 84   0.583783
# 86   0.586823
# 88   0.366785
# 90   0.500770
# 92   0.499382
# 94   0.530429
# 96   0.533491
# 98   0.534451
# 100  0.427548
# 102  0.578763
# 104  0.400828
# 106  0.573205
# 108  0.593015
# 110  0.499190
# 112  0.499758
# 114  0.505411
# 116  0.545827
# 118  0.524781
#
# [1920 rows x 8 columns]

# %% [markdown]
# ## Hierarchical GLAM estimation

# %% [markdown]
# ### 1. full GLAM

# %%
# Fitting full GLAM
print('Fitting full GLAM individually...')

glam_full = glam.GLAM(train_data)

if not os.path.exists(str('results/estimates/glam_PF2019_full'+sufix+'.npy')):
    glam_full.make_model('individual', gamma_bounds=(-1, 1), t0_val=0)
    glam_full.fit(method='NUTS', tune=1000)
else:
    print('  Found old parameter estimates in "results/estimates". Skipping estimation...')
    glam_full.estimates = np.load(str('results/estimates/glam_PF2019_full'+sufix+'.npy'))
# Out:
# Fitting full GLAM individually...
#   Found old parameter estimates in "results/estimates". Skipping estimation...

# %%
# Save parameter estimates
np.save(str('results/estimates/glam_PF2019_full'+sufix+'.npy'), glam_full.estimates)
pd.DataFrame(glam_full.estimates)
# Out:
#        SNR    b  gamma  p_error         s     t0   tau         v
# 0   133.85  1.0  -0.92     0.05  0.007718  [0.0]  0.01  0.000052
# 1   322.12  1.0  -0.99     0.05  0.006114  [0.0]  0.05  0.000016
# 2   195.74  1.0  -0.10     0.05  0.006339  [0.0]  0.14  0.000034
# 3   435.35  1.0  -0.99     0.05  0.008508  [0.0]  0.11  0.000021
# 4   169.32  1.0  -0.99     0.05  0.005410  [0.0]  0.06  0.000031
# 5   107.39  1.0  -0.70     0.05  0.005416  [0.0]  0.08  0.000058
# 6   219.15  1.0  -0.99     0.05  0.007774  [0.0]  0.09  0.000030
# 7   129.52  1.0  -0.99     0.05  0.006626  [0.0]  0.09  0.000051
# 8    48.38  1.0  -0.84     0.05  0.005459  [0.0]  0.00  0.000114
# 9   160.39  1.0  -0.99     0.05  0.009785  [0.0]  0.06  0.000055
# 10  239.45  1.0  -0.91     0.05  0.007605  [0.0]  0.03  0.000026
# 11   56.19  1.0  -0.96     0.05  0.005168  [0.0]  0.02  0.000082
# 12   85.09  1.0   0.95     0.05  0.002561  [0.0]  0.00  0.000033
# 13  251.57  1.0  -0.81     0.05  0.009641  [0.0]  0.26  0.000042
# 14  138.64  1.0  -0.96     0.05  0.006479  [0.0]  0.04  0.000045
# 15  157.31  1.0  -0.98     0.05  0.008105  [0.0]  0.08  0.000045
# 16  486.24  1.0  -0.99     0.05  0.008294  [0.0]  0.03  0.000018
# 17  168.95  1.0  -0.98     0.05  0.005192  [0.0]  0.05  0.000028
# 18  158.43  1.0  -0.88     0.05  0.008768  [0.0]  0.04  0.000032
# 19  169.82  1.0  -0.97     0.05  0.008778  [0.0]  0.03  0.000045
# 20  191.79  1.0  -0.98     0.05  0.006710  [0.0]  0.09  0.000032
# 21  171.92  1.0  -0.98     0.05  0.010861  [0.0]  0.06  0.000035
# 22  238.20  1.0  -0.99     0.05  0.007732  [0.0]  0.07  0.000030
# 23  146.31  1.0  -0.99     0.05  0.006475  [0.0]  0.04  0.000037
# 24  329.45  1.0  -0.99     0.05  0.006911  [0.0]  0.02  0.000017
# 25  168.99  1.0  -0.58     0.05  0.006710  [0.0]  0.06  0.000039
# 26  130.61  1.0  -0.99     0.05  0.004379  [0.0]  0.03  0.000029
# 27  201.86  1.0  -0.69     0.05  0.009143  [0.0]  0.15  0.000047
# 28   60.19  1.0  -0.99     0.05  0.003964  [0.0]  0.12  0.000069
# 29  130.35  1.0  -0.99     0.05  0.008675  [0.0]  0.06  0.000057
# 30  166.76  1.0  -0.99     0.05  0.006280  [0.0]  0.03  0.000042
# 31  154.12  1.0  -0.99     0.05  0.007231  [0.0]  0.05  0.000042

# %%
# Compute WAICs
print('Computing WAIC scores for full model...')
if not os.path.exists(str('results/waic/glam_PF2019_full'+ sufix +'.npy')):
    # Note: DIC computation does not work for ADVI fitted models
    # But we are using WAIC
    glam_full.compute_waic()
else:
    print('  Found old DIC scores in "results/waic". Skipping WAIC computation...')
    glam_full.waic = np.load(str('results/waic/glam_PF2019_full'+ sufix +'.npy'))
# Out:
# Computing WAIC scores for full model...
#   Found old DIC scores in "results/waic". Skipping WAIC computation...

# %%
# Compute WAICs
np.save(str('results/waic/glam_PF2019_full'+ sufix +'.npy'), glam_full.waic)
# Out:
# Computing WAIC scores for full model...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-bc337b458ea2> in <module>()
#       1 # Compute WAICs
#       2 print('Computing WAIC scores for full model...')
# ----> 3 if not os.path.exists(str('results/waic/glam_PF2019_full'+ sufix +'.npy')):
#       4     # Note: DIC computation does not work for ADVI fitted models
#       5     # But we are using WAIC
#
# NameError: name 'sufix' is not defined

# %%
len(glam_full.waic)
# Out:
# 32

# %%
glam_full.waic
# Out:
# array([[1.08857077e+03, 0.00000000e+00, 3.45932676e+00, 1.00000000e+00],
#        [1.20715525e+03, 0.00000000e+00, 2.29456155e+00, 1.00000000e+00],
#        [1.02985342e+03, 0.00000000e+00, 3.73365833e+00, 1.00000000e+00],
#        [1.21431435e+03, 0.00000000e+00, 2.98100994e+00, 1.00000000e+00],
#        [1.11921633e+03, 0.00000000e+00, 2.92709463e+00, 1.00000000e+00],
#        [1.00654760e+03, 0.00000000e+00, 2.28641263e+00, 1.00000000e+00],
#        [1.14949010e+03, 0.00000000e+00, 2.96548187e+00, 1.00000000e+00],
#        [1.03247261e+03, 0.00000000e+00, 2.33504832e+00, 1.00000000e+00],
#        [9.73383207e+02, 0.00000000e+00, 1.90855098e+00, 1.00000000e+00],
#        [1.06354325e+03, 0.00000000e+00, 3.69687773e+00, 1.00000000e+00],
#        [1.15597886e+03, 0.00000000e+00, 3.90855028e+00, 1.00000000e+00],
#        [1.00381184e+03, 0.00000000e+00, 3.40197448e+00, 1.00000000e+00],
#        [1.05424132e+03, 0.00000000e+00, 5.36931345e+00, 1.00000000e+00],
#        [1.07747746e+03, 0.00000000e+00, 2.50275226e+00, 1.00000000e+00],
#        [1.04980710e+03, 0.00000000e+00, 2.27138795e+00, 1.00000000e+00],
#        [1.06583430e+03, 0.00000000e+00, 5.87979953e+00, 1.00000000e+00],
#        [1.22126021e+03, 0.00000000e+00, 2.43229811e+00, 1.00000000e+00],
#        [1.11540976e+03, 0.00000000e+00, 3.17311702e+00, 1.00000000e+00],
#        [1.09797570e+03, 0.00000000e+00, 3.15665546e+00, 1.00000000e+00],
#        [1.10321373e+03, 0.00000000e+00, 2.68538217e+00, 1.00000000e+00],
#        [1.10044174e+03, 0.00000000e+00, 2.31317953e+00, 1.00000000e+00],
#        [1.11922595e+03, 0.00000000e+00, 2.88460669e+00, 1.00000000e+00],
#        [1.13374825e+03, 0.00000000e+00, 2.65429197e+00, 1.00000000e+00],
#        [1.10925203e+03, 0.00000000e+00, 4.00204347e+00, 1.00000000e+00],
#        [1.24120968e+03, 0.00000000e+00, 1.69495591e+00, 1.00000000e+00],
#        [1.08537560e+03, 0.00000000e+00, 2.12168574e+00, 1.00000000e+00],
#        [1.11052551e+03, 0.00000000e+00, 2.90026784e+00, 1.00000000e+00],
#        [1.04497101e+03, 0.00000000e+00, 3.62513560e+00, 1.00000000e+00],
#        [8.84180675e+02, 0.00000000e+00, 2.41204508e+00, 1.00000000e+00],
#        [1.02116466e+03, 0.00000000e+00, 4.08761275e+00, 1.00000000e+00],
#        [1.07154766e+03, 0.00000000e+00, 2.38436891e+00, 1.00000000e+00],
#        [1.09587503e+03, 0.00000000e+00, 3.22039824e+00, 1.00000000e+00]])

# %%
# Compute LOO

glam_full.loo = pm.loo(trace=glam_full.trace, model=glam_full.model)
glam_full.loo
np.save(str('results/loo/glam_PF2019_full'+ sufix +'.npy'), glam_full.loo)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-f3d14e55e290> in <module>()
#       1 # Compute LOO
#       2
# ----> 3 glam_full.loo = pm.loo(trace=glam_full.trace, model=glam_full.model)
#       4 glam_full.loo
#       5 np.save(str('results/loo/glam_PF2019_full'+ sufix +'.npy'), glam_full.loo)
#
# /anaconda3/lib/python3.7/site-packages/pymc3/stats.py in loo(trace, model, pointwise, reff, progressbar)
#     268
#     269     if reff is None:
# --> 270         if trace.nchains == 1:
#     271             reff = 1.
#     272         else:
#
# AttributeError: 'list' object has no attribute 'nchains'

# %%
glam_full.loo
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-12528b9778fa> in <module>()
# ----> 1 glam_full.loo
#
# AttributeError: 'GLAM' object has no attribute 'loo'

# %%
# Predictions
print('Predicting test set data using full GLAM...')
glam_full.exchange_data(test_data)

if not os.path.exists(str('results/predictions/glam_PF2019_full'+sufix+'.csv')):
    glam_full.predict(n_repeats=50)
    glam_full.prediction.to_csv(str('results/predictions/glam_PF2019_full'+sufix+'.csv'), index=False)
else:
    print('  Found old hierarchical full GLAM predictions in "results/predictions". Skipping prediction...')
    glam_full.prediction = pd.read_csv(str('results/predictions/glam_PF2019_full'+sufix+'.csv'))

glam_full.prediction.head()
# Out:
# Predicting test set data using full GLAM...
# Replaced attached data (1920 trials) with new data (1920 trials)...
#   Found old hierarchical full GLAM predictions in "results/predictions". Skipping prediction...
#    subject  trial  repeat  choice      rt  item_value_0    gaze_0  \
# 0      1.0    0.0     0.0     1.0  3310.0            47  0.490772
# 1      1.0    0.0     1.0     0.0  2781.0            47  0.490772
# 2      1.0    0.0     2.0     0.0  1608.0            47  0.490772
# 3      1.0    0.0     3.0     1.0  4290.0            47  0.490772
# 4      1.0    0.0     4.0     0.0  3031.0            47  0.490772
#
#    item_value_1    gaze_1
# 0            50  0.509228
# 1            50  0.509228
# 2            50  0.509228
# 3            50  0.509228
# 4            50  0.509228

# %% [markdown]
# ### 1. no-bias GLAM

# %%
# Fitting no-bias GLAM
print('Fitting no-bias GLAM hierarchically...')

glam_nobias = glam.GLAM(train_data)

if not os.path.exists(str('results/estimates/glam_PF2019_nobias_'+sufix+'.npy')):
    glam_nobias.make_model('hierarchical', gamma_val=1.0, t0_val=0)
    glam_nobias.fit(method='NUTS', tune=1000)
else:
    print('  Found old parameter estimates in "results/estimates". Skipping estimation...')
    glam_nobias.estimates = np.load(str('results/estimates/glam_PF2019_nobias'+sufix+'.npy'))

# %%
   
# Save parameter estimates
np.save(str('results/estimates/glam_PF2019_nobias_individual_cv'+sufix+'.npy'), glam_nobias.estimates)
pd.DataFrame(glam_nobias.estimates)

# %%
# In case it is already fitted
params_part_like = pd.DataFrame.from_dict(glam_nobias.estimates.item(0))
params_part_like

# %%
# Compute LOO

glam_nobias.loo = pm.loo(trace=glam_nobias.trace, model=glam_nobias.model)
glam_nobias.loo

np.save(str('results/loo/glam_PF2019_nobias'+ sufix +'.npy'), glam_nobias.loo
)

# %%
# Predictions
print('Predicting test set data using no-bias GLAM...')
glam_nobias.exchange_data(test_data)

if not os.path.exists(str('results/predictions/glam_PF2019_nobias'+sufix+'.csv')):
    glam_nobias.predict(n_repeats=50)
    glam_nobias.prediction.to_csv(str('results/predictions/glam_PF2019_nobias'+sufix+'.csv'), index=False)
else:
    print('  Found old hierarchical no-bias GLAM predictions in "results/predictions". Skipping prediction...')
    glam_nobias.prediction = pd.read_csv(str('results/predictions/glam_PF2019_nobias'+sufix+'.csv'))

glam_nobias.prediction.head()

# %% [markdown]
# ## 2. Plot fit

# %%
print('Close Figure to continue...')
glam.plot_fit(test_data, [glam_full.prediction]);
glam.plots_pretty.plot_fit(test_data, [glam_full.prediction]);

#glam.plot_fit(test_data, [glam_full.prediction,glam_nobias.prediction]);

plt.show()
# Out:
# Close Figure to continue...
# /anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:2448: UserWarning: Saw kwargs ['ms', 'markersize'] which are all aliases for 'markersize'.  Kept value from 'markersize'
#   seen=seen, canon=canonical, used=seen[-1]))

# %% [markdown]
# ## Parameters for full hierarchical model

# %%
params_participant = glam_full.estimates
params_participant
# Out:
# [{'b': 1.0,
#   'p_error': 0.05,
#   'v': 5.1e-05,
#   'gamma': -0.77,
#   'SNR': 125.41,
#   's': 0.0081,
#   'tau': 0.01,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 1.6e-05,
#   'gamma': -0.99,
#   'SNR': 290.78,
#   's': 0.006238,
#   'tau': 0.05,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 3.5e-05,
#   'gamma': -0.11,
#   'SNR': 230.96,
#   's': 0.008048,
#   'tau': 0.11,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 2.1e-05,
#   'gamma': -0.99,
#   'SNR': 434.59,
#   's': 0.009583,
#   'tau': 0.1,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 3.2e-05,
#   'gamma': -0.99,
#   'SNR': 165.04,
#   's': 0.005638,
#   'tau': 0.06,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 5.7e-05,
#   'gamma': -0.71,
#   'SNR': 83.7,
#   's': 0.005543,
#   'tau': 0.09,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 3e-05,
#   'gamma': -0.99,
#   'SNR': 232.79,
#   's': 0.008216,
#   'tau': 0.08,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 5.1e-05,
#   'gamma': -0.99,
#   'SNR': 99.14,
#   's': 0.005566,
#   'tau': 0.09,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 0.00011,
#   'gamma': -0.86,
#   'SNR': 49.13,
#   's': 0.005373,
#   'tau': 0.0,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 5.7e-05,
#   'gamma': -0.99,
#   'SNR': 165.72,
#   's': 0.008702,
#   'tau': 0.06,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 2.8e-05,
#   'gamma': -0.99,
#   'SNR': 326.55,
#   's': 0.008587,
#   'tau': 0.03,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 9e-05,
#   'gamma': -0.99,
#   'SNR': 54.42,
#   's': 0.004899,
#   'tau': 0.02,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 3.4e-05,
#   'gamma': -0.56,
#   'SNR': 86.39,
#   's': 0.002529,
#   'tau': 0.0,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 4e-05,
#   'gamma': -0.87,
#   'SNR': 232.26,
#   's': 0.00942,
#   'tau': 0.25,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 4.7e-05,
#   'gamma': -0.99,
#   'SNR': 154.16,
#   's': 0.006544,
#   'tau': 0.04,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 4.6e-05,
#   'gamma': -0.99,
#   'SNR': 127.67,
#   's': 0.007116,
#   'tau': 0.08,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 1.9e-05,
#   'gamma': -0.99,
#   'SNR': 476.5,
#   's': 0.008507,
#   'tau': 0.03,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 2.8e-05,
#   'gamma': -0.99,
#   'SNR': 177.22,
#   's': 0.005505,
#   'tau': 0.05,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 3.2e-05,
#   'gamma': -0.87,
#   'SNR': 340.23,
#   's': 0.008569,
#   'tau': 0.04,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 4.5e-05,
#   'gamma': -0.98,
#   'SNR': 228.98,
#   's': 0.008275,
#   'tau': 0.03,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 3.2e-05,
#   'gamma': -0.99,
#   'SNR': 213.49,
#   's': 0.006526,
#   'tau': 0.08,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 3.6e-05,
#   'gamma': -0.99,
#   'SNR': 288.26,
#   's': 0.009493,
#   'tau': 0.08,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 3e-05,
#   'gamma': -0.99,
#   'SNR': 232.13,
#   's': 0.007639,
#   'tau': 0.07,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 3.7e-05,
#   'gamma': -0.99,
#   'SNR': 133.67,
#   's': 0.006737,
#   'tau': 0.04,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 1.7e-05,
#   'gamma': -0.99,
#   'SNR': 336.19,
#   's': 0.007432,
#   'tau': 0.02,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 3.9e-05,
#   'gamma': -0.71,
#   'SNR': 145.41,
#   's': 0.006367,
#   'tau': 0.06,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 2.9e-05,
#   'gamma': -0.99,
#   'SNR': 141.85,
#   's': 0.004457,
#   'tau': 0.03,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 4.6e-05,
#   'gamma': -0.98,
#   'SNR': 259.96,
#   's': 0.010083,
#   'tau': 0.18,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 6.8e-05,
#   'gamma': -0.99,
#   'SNR': 62.69,
#   's': 0.004352,
#   'tau': 0.11,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 5.7e-05,
#   'gamma': -0.98,
#   'SNR': 115.24,
#   's': 0.008492,
#   'tau': 0.05,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 7.2e-05,
#   'gamma': 0.27,
#   'SNR': 106.53,
#   's': 0.008452,
#   'tau': 0.01,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 4.6e-05,
#   'gamma': -0.94,
#   'SNR': 145.61,
#   's': 0.006249,
#   'tau': 0.01,
#   't0': array([0.])},
#  {'b': 1.0,
#   'p_error': 0.05,
#   'v': 4.4e-05,
#   'gamma': -0.94,
#   'SNR': 156.31,
#   's': 0.007018,
#   'tau': 0.0,
#   't0': array([0.])}]

# %%
params_participant = pd.DataFrame.from_dict(glam_full.estimates.item(0))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-24a3f3602e89> in <module>()
# ----> 1 params_participant = glam_full.estimates.item(0)
#       2 params_participant = pd.DataFrame.from_dict(glam_full.estimates.item(0))
#
# AttributeError: 'list' object has no attribute 'item'

# %%
params_participant

# %%
print ("Mean gamma " +  str(params_participant['gamma'].mean()))

# %%
hist = params_participant[['SNR','gamma','tau','v']].hist(figsize = [20,3] , layout=[1,4],bins = 20)

# %% [markdown]
# ## [END]
